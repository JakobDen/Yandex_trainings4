# %%
def some_power(p, i):
    if i == 0:
        return 1
    if i % 2 == 0:
        return (some_power(p, i // 2) ** 2) % 618970019642690137449562111
    else:
        return (p * some_power(p, i - 1)) % 618970019642690137449562111


with open('input.txt', 'r') as f:
    s = f.readline().strip()
    n = int(f.readline())
    p1 = 2
    p2 = 7
    other_p = 618970019642690137449562111
    prev1, prev2 = 1, 1
    encoded1 = []
    encoded2 = []

    for ch in s:
        encoded1.append(ord(ch) * prev1)
        prev1 = (prev1 * p1) % other_p
        
        encoded2.append(ord(ch) * prev2)
        prev2 = (prev2 * p2) % other_p

    prefixsum1 = [0]
    prefixsum2 = [0]
    currsum1 = 0
    currsum2 = 0
    for ever in encoded1:
        currsum1 += ever
        prefixsum1.append(currsum1)

    for ever in encoded2:
        currsum2 += ever
        prefixsum2.append(currsum2)
        
    for i in range(n):
        L, A, B = list(map(int, f.readline().strip().split()))
        A, B = max(A, B), min(A, B)
        substr11 = (prefixsum1[A + L] - prefixsum1[A]) % other_p
        substr21 = ((prefixsum1[B + L] - prefixsum1[B]) * some_power(p1, A - B)) % other_p
        
        substr12 = (prefixsum2[A + L] - prefixsum2[A]) % other_p
        substr22 = ((prefixsum2[B + L] - prefixsum2[B]) * some_power(p2, A - B)) % other_p
        
        if substr11 == substr21 and substr12 == substr22:
            if s[A: A + L] == s[B: B + L]:
                print('yes')
            else:
                print('no')
        else:
            print('no')
# Out:
# yes
# yes
# yes
# no
# yes
# yes
# yes
# no
# no
# yes
# no
# yes
# no
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# no
# yes
# yes
# no
# no
# no
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# no
# no
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# no
# no
# yes
# yes
# no
# no
# yes
# yes
# yes
# no
# no
# yes
# no
# no
# no
# no
# yes
# no
# yes
# no
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# no
# yes
# no
# yes
# yes
# yes
# yes
# no
# no
# no
# no
# yes
# yes
# yes
# yes
# no
# yes
# no
# yes
# no
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# no
# yes
# no
# yes
# no
# yes
# yes
# no
# yes
# yes
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# no
# yes
# no
# yes
# no
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# no
# no
# yes
# yes
# no
# yes
# yes
# yes
# yes
# no
# yes
# no
# no
# ...

# %%
def some_power(p, i):
    if i == 0:
        return 1
    if i % 2 == 0:
        return (some_power(p, i // 2) ** 2) % 618970019642690137449562111
    else:
        return (p * some_power(p, i - 1)) % 618970019642690137449562111

s = input().strip()
if len(s) > 1:
    p1 = 7
    other_p = 618970019642690137449562111
    prev1 = 1
    encoded1 = []

    for ch in s:
        encoded1.append(ord(ch) * prev1)
        prev1 = (prev1 * p1) % other_p
            
    prefixsum1 = [0]
    currsum1 = 0

    for ever in encoded1:
        currsum1 = (currsum1 + ever) % 618970019642690137449562111
        prefixsum1.append(currsum1)

    def check(L):
        if L <= 0:
            return False
        i = 2
        pref_code = prefixsum1[L]
        while i < len(s) // L:
            if ((prefixsum1[L * i] - prefixsum1[L * (i - 1)] - pref_code * some_power(p1, L * (i - 1)))  % 618970019642690137449562111) != 0:
                return False
            i += 1
        return True

    
    r = (len(s))//2
    answer = 0

    while r >= 1:
        if check(r):
            answer = r
        r -= 1 
    print(answer)
else:
    print(len(s))
# Out:
# 3

# %%
s
# Out:
# '111222'

# %% [markdown]
# ## Хэши для строк

# %%
class HashIt():
    def __init__(self, data, p = 5, ring = 10 ** 9 + 7):
        self.h = [0] * (len(data) + 1)
        self.ring = ring
        self.powers = [1]
        
        x = 1
        for i, ch in enumerate(data, 1):
            self.h[i] = (self.h[i - 1] * p + ord(ch)) % ring
            x = (x * p) % ring
            self.powers.append(x)
            
    def isequal(self, s1, s2, l):
        return (self.h[s1 + l] + self.h[s2] * self.powers[l]) % self.ring ==\
            (self.h[s2 + l] + self.h[s1] * self.powers[l]) % self.ring
        
f = open('input.txt', 'r')
s = f.readline().strip()
n = int(f.readline())

encoded1 = HashIt(s, 5)
encoded2 = HashIt(s, 7)

for i in range(n):
    L, A, B = list(map(int, f.readline().strip().split()))
    if encoded1.isequal(A, B, L):
        if encoded2.isequal(A, B, L):
            print('yes')
        else:
            print('no')
    else:
        print('no')
        
f.close()
# Out:
# no
# no
# no
# no
# no
# no
# yes
# yes
# yes
# no

# %%
class HashIt():
    def __init__(self, data, p = 5, ring = 10 ** 9 + 7):
        self.h = [0] * (len(data) + 1)
        self.ring = ring
        self.powers = [1]
        
        x = 1
        for i, ch in enumerate(data, 1):
            self.h[i] = (self.h[i - 1] * p + ord(ch)) % ring
            x = (x * p) % ring
            self.powers.append(x)
            
    def isequal(self, s1, s2, l):
        return (self.h[s1 + l] + self.h[s2] * self.powers[l]) % self.ring ==\
            (self.h[s2 + l] + self.h[s1] * self.powers[l]) % self.ring
        
s = input().strip()
slen = len(s)

encoded1 = HashIt(s, 5)
encoded2 = HashIt(s, 7)

l = 0
prefixlen = 0

while l < len(s):
    if encoded1.isequal(0, slen - l, l):
        if encoded2.isequal(0, slen - l, l):
            prefixlen = l
    l += 1
print(slen - prefixlen)
# Out:
# 1

# %%
class HashIt():
    def __init__(self, data, p = 5, ring = 10 ** 9 + 7):
        self.h = [0] * (len(data) + 1)
        self.ring = ring
        self.powers = [1]
        
        x = 1
        for i, ch in enumerate(data, 1):
            self.h[i] = (self.h[i - 1] * p + ord(ch)) % ring
            x = (x * p) % ring
            self.powers.append(x)
            
    def isequal(self, s1, s2, l):
        return (self.h[s1 + l] + self.h[s2] * self.powers[l]) % self.ring ==\
            (self.h[s2 + l] + self.h[s1] * self.powers[l]) % self.ring
        
s = input().strip()
slen = len(s)

encoded1 = HashIt(s, 5)
encoded2 = HashIt(s, 7)

Z = [0] * slen

for i in range(1, slen):
    l = 0
    r = slen - i
    zval = 0
    while l <= r:
        mid = (r + l) // 2
        if encoded1.isequal(0, i, mid):
            zval = mid
            l = mid + 1
        else:
            r = mid - 1
    Z[i] = zval

print(*Z)
# Out:
# 0 0 0 1 0 1 0 4 0 0 1

# %%
s = input().strip()

z = [0] * len(s)
l = 0
r = 0

for i in range(1, len(s)):
    zmin = 0
    if l <= i < r:
        zmin = min(r - i, z[i - l])
    while (i + zmin < len(s)) and s[i + zmin] == s[zmin]:
        zmin += 1
    if i + zmin > r:
        l = i
        r = i + zmin
    z[i] = zmin
print(*z)
# Out:
# 0 0 1 0 3 0 2 0

# %%
class HashIt():
    def __init__(self, data, p = 5, ring = 10 ** 9 + 7):
        self.h = [0] * (len(data) + 1)
        self.ring = ring
        self.powers = [1]
        
        x = 1
        for i, ch in enumerate(data, 1):
            self.h[i] = (self.h[i - 1] * p + ch) % ring
            x = (x * p) % ring
            self.powers.append(x)
    def get_hash(self, s1, l):
        return (self.h[s1 + l] - self.h[s1] * self.powers[l] + self.ring) % self.ring
            
n, m = list(map(int, input().strip().split()))
S = list(map(int, input().strip().split()))

avers_encoded = HashIt(S, 7)
revers_encoded = HashIt(S[::-1], 7)


mirror = n // 2
while mirror >= 0:
    if avers_encoded.get_hash(0, mirror) == revers_encoded.get_hash(n - 2 * mirror, mirror):
        print(n - mirror, end = ' ')
    mirror -= 1
# Out:
# 3 5 6

# %%
class HashIt():
    def __init__(self, data, p = 3, ring = 909090909090909091):
        self.h = [0] * (len(data) + 1)
        self.ring = ring
        self.powers = [1]
        
        x = 1
        for i, ch in enumerate(data, 1):
            self.h[i] = (self.h[i - 1] * p + ord(ch)) % ring
            x = (x * p) % ring
            self.powers.append(x)
    def get_hash(self, s1, l):
        return (self.h[s1 + l] - self.h[s1] * self.powers[l]) % self.ring
    
S = input().strip()
answer = 0

avers_encoded = HashIt(S, 37)
revers_encoded = HashIt(S[::-1], 37)

for i in range(len(S)):
    l = 0
    r = min(len(S) - i - 1, i)
    l1 = 0
    r1 = min(len(S) - i, i)
    d1, d2 = 0, 0
    while (l <= r) or (l1 <= r1):
        mid = (l + r) // 2
        mid1 = (l1 + r1) // 2
        if (avers_encoded.get_hash(i + 1, mid) == revers_encoded.get_hash(len(S) - i, mid)):
            d1 = mid
            l = mid + 1
        else:
            r = mid - 1
            
        if (avers_encoded.get_hash(i, mid1) == revers_encoded.get_hash(len(S) - i, mid1)):
            d2 = mid1
            l1 = mid1 + 1
        else:
            r1 = mid1 - 1
            
    answer += 1 + d1 + d2
    
print(answer)
# Out:
# 112

# %%
class HashIt():
    def __init__(self, data, p = 3, ring = 99990001):
        self.h1 = [0] * (len(data) + 1)
        self.h2 = [0] * (len(data) + 1)
        self.ring = ring
        self.powers = [1]
        self.Slen = len(data) 
               
        x = 1
        for i, ch in enumerate(data, 1):
            self.h1[i] = (self.h1[i - 1] * p + ord(ch)) % ring
            self.h2[i] = (self.h2[i - 1] * p + ord(data[len(data) - i])) % ring
            x = (x * p) % ring
            self.powers.append(x)
            
    def get_hash_avers(self, s1, l):
        return (self.h1[s1 + l] - self.h1[s1] * self.powers[l])
    def get_hash_revers(self, s1, l):
        return (self.h2[s1 + l] - self.h2[s1] * self.powers[l])
    def checkI(self, s1, l):
        encoded.get_hash_avers(i + 1, mid) - encoded.get_hash_revers(len(S) - i, mid))
        return (self.h1[s1 + 1 + l] + self.h2[s1] * self.powers[l]) == (self.h2[s1 + l] + self.h1[s1] * self.powers[l])
        


with open('/Users/jacob/Downloads/45.file', 'r') as f:
    S = f.readline().strip()
    
answer = 0

encoded = HashIt(S, 17)

for i in range(len(S)):
    l = 0
    r = min(len(S) - i - 1, i)
    l1 = 0
    r1 = min(len(S) - i, i)
    d1, d2 = 0, 0
    while (l <= r) or (l1 <= r1):
        mid = (l + r) // 2
        mid1 = (l1 + r1) // 2
        if ((encoded.get_hash_avers(i + 1, mid) - encoded.get_hash_revers(len(S) - i, mid)) % (99990001)) == 0:
            d1 = mid
            l = mid + 1
        else:
            r = mid - 1
            
        if ((encoded.get_hash_avers(i, mid1) - encoded.get_hash_revers(len(S) - i, mid1)) % (99990001)) == 0:
            d2 = mid1
            l1 = mid1 + 1
        else:
            r1 = mid1 - 1
    answer += 1 + d1 + d2
    
print(answer)
# Out:
# 100000
